# %%
# !pip install biopython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 2.7/2.7 MB 3.3 MB/s eta 0:00:00
# ...

# %%
from Bio.PDB.MMCIF2Dict import MMCIF2Dict
from Bio.PDB import MMCIFParser
import pandas as pd
import requests

# %%
# Downlaod the mmCIF file
url = 'https://files.rcsb.org/view/7CGT.cif'

response = requests.get(url)

# Save the content to a local file
with open('7CGT.cif', 'wb') as f:
    f.write(response.content)

# %%
from Bio.PDB.MMCIF2Dict import MMCIF2Dict
import pandas as pd

# Load the MMCIF file into a dictionary
mmcif_dict = MMCIF2Dict("7CGT.cif")

# Initialize an empty dictionary to hold our tables
tables = {}

# Loop over each key in the MMCIF dictionary
for key in mmcif_dict.keys():
    # Split the key into its components
    components = key.split(".")
    if len(components) < 2:
        continue

    # The table name is the first component of the key
    table_name = components[0]

    # Initialize the table dictionary if it doesn't exist yet
    if table_name not in tables:
        tables[table_name] = {}

    # Add the data to the appropriate table
    tables[table_name][key] = mmcif_dict[key]

# Convert each table dictionary to a DataFrame
dfs = {table_name: pd.DataFrame(table_data) for table_name, table_data in tables.items()}

# Now, 'dfs' is a dictionary of DataFrames, keyed by table name
# You can access individual tables like so:
dfs['_atom_site'].head()

# %%
dfs['_atom_site'].head()
# Out:
#   _atom_site.group_PDB _atom_site.id _atom_site.type_symbol  \
# 0                 ATOM             1                      N
# 1                 ATOM             2                      C
# 2                 ATOM             3                      C
# 3                 ATOM             4                      O
# 4                 ATOM             5                      C
#
#   _atom_site.label_atom_id _atom_site.label_alt_id _atom_site.label_comp_id  \
# 0                        N                       .                      ASP
# 1                       CA                       .                      ASP
# 2                        C                       .                      ASP
# 3                        O                       .                      ASP
# 4                       CB                       .                      ASP
#
#   _atom_site.label_asym_id _atom_site.label_entity_id _atom_site.label_seq_id  \
# ...

# %%
# Initialize the MMCIF parser
parser = MMCIFParser()

# Load the structure from the mmCIF file
structure = parser.get_structure("protein_name", "7CGT.cif")

# Iterate through the structure and print some information
for model in structure:
    for chain in model:
        for residue in chain:
            for atom in residue:
                print(atom)
# Out:
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG>
# <Atom OD1>
# <Atom OD2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG>
# <Atom CD>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG>
# <Atom OD1>
# <Atom OD2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom OG1>
# <Atom CG2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG1>
# <Atom CG2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom OG1>
# <Atom CG2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG>
# <Atom OD1>
# <Atom ND2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG>
# <Atom CD>
# <Atom CE>
# <Atom NZ>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom CG>
# <Atom CD>
# <Atom OE1>
# <Atom NE2>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# <Atom CB>
# <Atom OG>
# <Atom N>
# <Atom CA>
# <Atom C>
# <Atom O>
# ...
